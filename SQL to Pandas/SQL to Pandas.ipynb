# %% [markdown]
# # Translating SQL to Pandas

# %% [markdown]
# ## Table of Contents
# 1. [What is Pandas ?](#Pandas)
# 2. [What is SQL ?](#SQL)
#     1. [Structure of SQL Query](#Anatomy)
# 3. [Examples](#Examples)
#     1. [SELECT](#select)
#     2. [JOIN](#join)
#     3. [ORDER BY](#order)
#     4. [IN ... NO IN](#in)
#     5. [GROUP BY, COUNT, ORDER BY](#groupby)
#     6. [HAVING](#having)
#     7. [TOP N RECORDS](#records)
#     8. [MIN, MAX and MEAN](#Agg)
#     9. [UNION and UNION ALL](#Union)

# %% [markdown]
# ## What is Pandas ? <a id ='Pandas'></a>

# %% [markdown]
# Python Data Analysis Library, called Pandas, is a Python library built for data analysis and manipulation. It’s open-source and supported by Anaconda. It is particularly well suited for structured (tabular) data. It is heavily used in data science and machine learning python based projects.
#
# For more information, visit [here](https://pandas.pydata.org/)

# %% [markdown]
# ## What is SQL ? <a id ='SQL'></a>

# %% [markdown]
# SQL stands for Structured Query Language. A query language is a kind of programming language that's designed to facilitate retrieving specific information from databases, and that's exactly what SQL does. To put it simply, SQL is the language of databases.
#
# For more information, visit [here](https://www.dataquest.io/blog/sql-basics/)

# %% [markdown]
# ### Structure of SQL Query <a id ='Anatomy'></a>

# %% [markdown]
# A SQL query consists of a few important keywords. Between those keywords, you add the specifics of what data, exactly, you want to see. Here is a skeleton query without the specifics:
#
# **SELECT… FROM… WHERE… <br>
# GROUP BY… HAVING… <br>
# ORDER BY… <br>
# LIMIT… OFFSET… <br>**

# %% [markdown]
# There are other terms, but these are the most important ones.
#
# **NOTE: To simulate SQL queries I will be using panadasql.**<br>
# For more information about the library, vist [here](https://pypi.org/project/pandasql/).

# %% [markdown]
# ## So how do we translate these terms into Pandas? Let's Begin.. <a id ='Examples'></a>

# %%
# Pandas
import pandas as pd

# Pandas SQL
import pandasql as ps

airports= pd.read_csv('airports.csv')
airport_freq = pd.read_csv('airport-frequencies.csv')
runways = pd.read_csv('runways.csv')

# %% [markdown]
# Data Source: https://ourairports.com/data/

# %% [markdown]
# ### SELECT Queries<a id ='select'></a>

# %% [markdown]
# The **SELECT** statement is used to select data from a database. The data returned is stored in a result table, called the result-set.
#
# For more information, click [here](#https://www.w3schools.com/sql/sql_select.asp)

# %% [markdown]
# | |                      SQL                     |                 Pandas                |
# |-|:--------------------------------------------:|:-------------------------------------:|
# |1| select * from airports                       | airports                              |
# |2| select * from airports limit 3               | airports.head(3)                      |
# |3| select id from airports where ident = 'KLAX' | airports[airports.ident == 'KLAX'].id |
# |4| select distinct type from airport            | airports.type.unique()                |

# %% [markdown]
# Here are some **SELECT** statements. We truncate results with **LIMIT**, and filter them with **WHERE**. We use **DISTINCT** to remove duplicated results.

# %% [markdown]
# #### Example Qquery 1: Select all airports

# %%
#Commented out due to long printout 
#ps.sqldf('select * from airports')

# %%
#Commented out due to long printout
#airports

# %% [markdown]
# #### Example Query 2: Select all airports and display first 3 results

# %%
ps.sqldf('select * from airports limit 3')
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total Rf Heliport     40.070801
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.949200
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933601          11.0      None          US      US-PA      Bensalem
# 1    -101.473911        3435.0      None          US      US-KS         Leoti
# 2    -151.695999         450.0      None          US      US-AK  Anchor Point
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# 0                no      00A      None        00A      None           None
# 1                no     00AA      None       00AA      None           None
# 2                no     00AK      None       00AK      None           None
#
#   keywords
# 0     None
# 1     None
# 2     None

# %%
airports.head(3)
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total Rf Heliport     40.070801
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.949200
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933601          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.695999         450.0       NaN          US      US-AK  Anchor Point
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# 0                no      00A       NaN        00A       NaN            NaN
# 1                no     00AA       NaN       00AA       NaN            NaN
# 2                no     00AK       NaN       00AK       NaN            NaN
#
#   keywords
# 0      NaN
# 1      NaN
# 2      NaN

# %% [markdown]
# #### Example Query 3: display airport id where ident is KLAX

# %%
ps.sqldf('select id from airports where ident = "KLAX"')
# Out:
#      id
# 0  3632

# %%
airports[airports.ident == 'KLAX'].id
# Out:
# 30803    3632
# Name: id, dtype: int64

# %% [markdown]
# #### Example Query 4: Display types of airports

# %%
ps.sqldf('select distinct type from airports')
# Out:
#              type
# 0        heliport
# 1   small_airport
# 2          closed
# 3   seaplane_base
# 4     balloonport
# 5  medium_airport
# 6   large_airport

# %%
airports.type.unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %% [markdown]
# ### JOIN <a id ='join'></a>

# %% [markdown]
# A **JOIN** clause is used to combine rows from two or more tables, based on a related column between them.
#
# For more information, click [here](https://www.w3schools.com/sql/sql_join.asp)

# %% [markdown]
# |                                                  SQL                                                 |                                                       Pandas                                                       |
# |:----------------------------------------------------------------------------------------------------:|:------------------------------------------------------------------------------------------------------------------:|
# | select * from airports where iso_region = 'US-CA' and type = 'seaplane_base'                         | airports[(airports.iso_region == 'US-CA') & (airports.type == 'seaplane_base')]                                    |
# | select ident, name, municipality from airports where iso_region = 'US-CA' and type = 'large_airport' | airports[(airports.iso_region == 'US-CA') & (airports.type == 'large_airport')][['ident', 'name', 'municipality']] |

# %% [markdown]
# We join multiple conditions with an &. If we only want a subset of columns from the table, that subset is applied in another pair of square brackets.

# %% [markdown]
# #### Example Query 1: Display all airports where region is 'US-CA' and airport type is 'seaplane_base'

# %%
ps.sqldf('select * from airports where iso_region = "US-CA" and type = "seaplane_base"')
# Out:
#         id ident           type                                      name  \
# 0     7436   0O0  seaplane_base          San Luis Reservoir Seaplane Base
# 1     8877  22CA  seaplane_base            Commodore Center Seaplane Base
# 2    12298  5CA9  seaplane_base       Konocti  - Clear Lake Seaplane Base
# 3    16514   C39  seaplane_base                 Folsom Lake Seaplane Base
# 4    16830  CN20  seaplane_base             Ferndale Resort Seaplane Base
# 5    17157   E20  seaplane_base              Lake Berryessa Seaplane Base
# 6    17613   H77  seaplane_base           Bridge Bay Resort Seaplane Base
# 7    21444   L11  seaplane_base                Pebbly Beach Seaplane Base
# 8    23479   O06  seaplane_base  Lake Oroville Landing Area Seaplane Base
# 9    24384   S74  seaplane_base                   Lost Isle Seaplane Base
# 10  300312   TWH  seaplane_base           Two Harbors Amphibious Terminal
#
#     latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0      37.058300    -121.125999         544.0      None          US
# 1      37.878893    -122.512697           NaN      None          US
# 2      38.977699    -122.718002        1326.0      None          US
# 3      38.707199    -121.133003         466.0      None          US
# 4      39.002998    -122.796997        1326.0      None          US
# 5      38.550979    -122.227682         440.0      None          US
# 6      40.757599    -122.322998        1065.0      None          US
# 7      33.338402    -118.311996           NaN      None          US
# 8      39.566601    -121.468002         900.0      None          US
# 9      38.004101    -121.457001           NaN      None          US
# 10     33.432222    -118.508611           NaN      None          US
#
#    iso_region municipality scheduled_service gps_code iata_code local_code  \
# 0       US-CA    Los Banos                no      0O0      None        0O0
# 1       US-CA  Mill Valley                no     22CA      None       22CA
# 2       US-CA  Kelseyville                no     5CA9      None       5CA9
# 3       US-CA       Folsom                no      C39      None        C39
# 4       US-CA  Kelseyville                no     CN20      None       CN20
# 5       US-CA         Napa                no     None      None        E20
# 6       US-CA      Redding                no      H77      None        H77
# 7       US-CA       Avalon                no     KL11      None        L11
# 8       US-CA     Oroville                no      O06      None        O06
# 9       US-CA     Stockton                no      S74      None        S74
# 10      US-CA  Two Harbors                no     None       TWH       None
#
#    home_link wikipedia_link keywords
# 0       None           None     None
# 1       None           None     None
# 2       None           None     None
# 3       None           None     None
# 4       None           None     None
# 5       None           None     None
# 6       None           None     None
# 7       None           None     None
# 8       None           None     None
# 9       None           None     None
# 10      None           None     None

# %% [markdown]
# #### Example Query 2: Display ident, name and municipality in the region of 'US-CA' and airport type is 'large_airport'

# %%
airports[(airports.iso_region == 'US-CA') & (airports.type == 'seaplane_base')]
# Out:
#            id ident           type                                      name  \
# 988      7436   0O0  seaplane_base          San Luis Reservoir Seaplane Base
# 2514     8877  22CA  seaplane_base            Commodore Center Seaplane Base
# 6297    12298  5CA9  seaplane_base       Konocti  - Clear Lake Seaplane Base
# 14075   16514   C39  seaplane_base                 Folsom Lake Seaplane Base
# 16456   16830  CN20  seaplane_base             Ferndale Resort Seaplane Base
# 18872   17157   E20  seaplane_base              Lake Berryessa Seaplane Base
# 24545   17613   H77  seaplane_base           Bridge Bay Resort Seaplane Base
# 33551   21444   L11  seaplane_base                Pebbly Beach Seaplane Base
# 40729   23479   O06  seaplane_base  Lake Oroville Landing Area Seaplane Base
# 44645   24384   S74  seaplane_base                   Lost Isle Seaplane Base
# 52293  300312   TWH  seaplane_base           Two Harbors Amphibious Terminal
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 988       37.058300    -121.125999         544.0       NaN          US
# 2514      37.878893    -122.512697           NaN       NaN          US
# 6297      38.977699    -122.718002        1326.0       NaN          US
# 14075     38.707199    -121.133003         466.0       NaN          US
# 16456     39.002998    -122.796997        1326.0       NaN          US
# 18872     38.550979    -122.227682         440.0       NaN          US
# 24545     40.757599    -122.322998        1065.0       NaN          US
# 33551     33.338402    -118.311996           NaN       NaN          US
# 40729     39.566601    -121.468002         900.0       NaN          US
# 44645     38.004101    -121.457001           NaN       NaN          US
# 52293     33.432222    -118.508611           NaN       NaN          US
#
#       iso_region municipality scheduled_service gps_code iata_code local_code  \
# 988        US-CA    Los Banos                no      0O0       NaN        0O0
# 2514       US-CA  Mill Valley                no     22CA       NaN       22CA
# 6297       US-CA  Kelseyville                no     5CA9       NaN       5CA9
# 14075      US-CA       Folsom                no      C39       NaN        C39
# 16456      US-CA  Kelseyville                no     CN20       NaN       CN20
# 18872      US-CA         Napa                no      NaN       NaN        E20
# 24545      US-CA      Redding                no      H77       NaN        H77
# 33551      US-CA       Avalon                no     KL11       NaN        L11
# 40729      US-CA     Oroville                no      O06       NaN        O06
# 44645      US-CA     Stockton                no      S74       NaN        S74
# 52293      US-CA  Two Harbors                no      NaN       TWH        NaN
#
#       home_link wikipedia_link keywords
# 988         NaN            NaN      NaN
# 2514        NaN            NaN      NaN
# 6297        NaN            NaN      NaN
# 14075       NaN            NaN      NaN
# 16456       NaN            NaN      NaN
# 18872       NaN            NaN      NaN
# 24545       NaN            NaN      NaN
# 33551       NaN            NaN      NaN
# 40729       NaN            NaN      NaN
# 44645       NaN            NaN      NaN
# 52293       NaN            NaN      NaN

# %% [markdown]
# |                                                                               SQL                                                                              |                                                                                    Pandas                                                                                    |
# |:--------------------------------------------------------------------------------------------------------------------------------------------------------------:|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------:|
# | ps.sqldf('select airport_ident, airport_freq.type, description, frequency_mhz from airport_freq join airports on airport_freq.airport_ref = airports.id where airports.ident = "KLAX"') | airport_freq.merge(airports[airports.ident == 'KLAX'][['id']], left_on='airport_ref', right_on='id', how='inner')[['airport_ident', 'type', 'description', 'frequency_mhz']] |

# %% [markdown]
# #### Example Query: Join airports and airport_freq tables where ident is 'KLAX' and display the ident, type, description and frequency_mhz

# %%
ps.sqldf('select airport_ident, airport_freq.type, description, frequency_mhz from airport_freq\
         join airports on airport_freq.airport_ref = airports.id where airports.ident = "KLAX"')
# Out:
#    airport_ident  type description  frequency_mhz
# 0           KLAX   APP   SOCAL APP          36.07
# 1           KLAX   APP   SOCAL APP         124.30
# 2           KLAX  ATIS        ATIS         133.80
# 3           KLAX   CLD    CLNC DEL         121.40
# 4           KLAX   DEP   SOCAL DEP         124.30
# 5           KLAX   GND         GND         121.65
# 6           KLAX  MISC          CG          34.50
# 7           KLAX  MISC          CG         898.40
# 8           KLAX   OPS          AF          37.22
# 9           KLAX   TWR         TWR         119.80
# 10          KLAX  UNIC      UNICOM         122.95

# %%
airport_freq.merge(airports[airports.ident == 'KLAX'][['id']],
                   left_on='airport_ref', right_on='id', how='inner')[
                        ['airport_ident', 'type', 'description', 'frequency_mhz']]
# Out:
#    airport_ident  type description  frequency_mhz
# 0           KLAX   APP   SOCAL APP          36.07
# 1           KLAX   APP   SOCAL APP         124.30
# 2           KLAX  ATIS        ATIS         133.80
# 3           KLAX   CLD    CLNC DEL         121.40
# 4           KLAX   DEP   SOCAL DEP         124.30
# 5           KLAX   GND         GND         121.65
# 6           KLAX  MISC          CG          34.50
# 7           KLAX  MISC          CG         898.40
# 8           KLAX   OPS          AF          37.22
# 9           KLAX   TWR         TWR         119.80
# 10          KLAX  UNIC      UNICOM         122.95

# %% [markdown]
# ### ORDER BY <a id ='order'></a>

# %% [markdown]
# The **ORDER BY** keyword is used to sort the result-set in ascending or descending order. By default, it orders by ascending format.
#
# For more information, click [here](https://www.w3schools.com/sql/sql_orderby.asp)

# %% [markdown]
# |                                     SQL                                    |                                          Pandas                                         |
# |:--------------------------------------------------------------------------:|:---------------------------------------------------------------------------------------:|
# | select * from airport_freq where airport_ident = 'KLAX' order by type      | airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type')                  |
# | select * from airport_freq where airport_ident = 'KLAX' order by type desc | airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type', ascending=False) |

# %% [markdown]
# #### Example Query 1: Display all airports frequency where the ident is 'Klax' and order the results ascending by type

# %%
ps.sqldf('select * from airport_freq where airport_ident = "KLAX" order by type')
# Out:
#        id  airport_ref airport_ident  type description  frequency_mhz
# 0   60767         3632          KLAX   APP   SOCAL APP          36.07
# 1   60766         3632          KLAX   APP   SOCAL APP         124.30
# 2   60768         3632          KLAX  ATIS        ATIS         133.80
# 3   60769         3632          KLAX   CLD    CLNC DEL         121.40
# 4   60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 5   60771         3632          KLAX   GND         GND         121.65
# 6   60772         3632          KLAX  MISC          CG          34.50
# 7   60773         3632          KLAX  MISC          CG         898.40
# 8   60774         3632          KLAX   OPS          AF          37.22
# 9   60775         3632          KLAX   TWR         TWR         119.80
# 10  60776         3632          KLAX  UNIC      UNICOM         122.95

# %%
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type')
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11957  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11958  60766         3632          KLAX   APP   SOCAL APP         124.30
# 11959  60768         3632          KLAX  ATIS        ATIS         133.80
# 11960  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11961  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11962  60771         3632          KLAX   GND         GND         121.65
# 11963  60772         3632          KLAX  MISC          CG          34.50
# 11964  60773         3632          KLAX  MISC          CG         898.40
# 11965  60774         3632          KLAX   OPS          AF          37.22
# 11966  60775         3632          KLAX   TWR         TWR         119.80
# 11967  60776         3632          KLAX  UNIC      UNICOM         122.95

# %% [markdown]
# #### Example Query 2: Display all airports frequency where the ident is 'Klax' and order the results descending by type

# %%
ps.sqldf('select * from airport_freq where airport_ident = "KLAX" order by type desc')
# Out:
#        id  airport_ref airport_ident  type description  frequency_mhz
# 0   60776         3632          KLAX  UNIC      UNICOM         122.95
# 1   60775         3632          KLAX   TWR         TWR         119.80
# 2   60774         3632          KLAX   OPS          AF          37.22
# 3   60772         3632          KLAX  MISC          CG          34.50
# 4   60773         3632          KLAX  MISC          CG         898.40
# 5   60771         3632          KLAX   GND         GND         121.65
# 6   60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 7   60769         3632          KLAX   CLD    CLNC DEL         121.40
# 8   60768         3632          KLAX  ATIS        ATIS         133.80
# 9   60767         3632          KLAX   APP   SOCAL APP          36.07
# 10  60766         3632          KLAX   APP   SOCAL APP         124.30

# %%
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type', ascending=False)
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11967  60776         3632          KLAX  UNIC      UNICOM         122.95
# 11966  60775         3632          KLAX   TWR         TWR         119.80
# 11965  60774         3632          KLAX   OPS          AF          37.22
# 11963  60772         3632          KLAX  MISC          CG          34.50
# 11964  60773         3632          KLAX  MISC          CG         898.40
# 11962  60771         3632          KLAX   GND         GND         121.65
# 11961  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11960  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11959  60768         3632          KLAX  ATIS        ATIS         133.80
# 11957  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11958  60766         3632          KLAX   APP   SOCAL APP         124.30

# %% [markdown]
# ### IN… NOT IN<a id ='in'></a>
#
# The **IN** operator allows you to specify multiple values in a **WHERE** clause. The **IN** operator is a shorthand for multiple **OR** conditions.
#
# For more information, click [here](https://www.w3schools.com/sql/sql_in.asp)

# %% [markdown]
# |                                  SQL                                 |                           Pandas                           |
# |:--------------------------------------------------------------------:|:----------------------------------------------------------:|
# | select * from airports where type in ('heliport', 'balloonport')     | airports[airports.type.isin(['heliport', 'balloonport'])]  |
# | select * from airports where type not in ('heliport', 'balloonport') | airports[~airports.type.isin(['heliport', 'balloonport'])] |

# %% [markdown]
# #### Example Query 1: Display all airports who are either heliport or ballonport

# %%
ps.sqldf('select * from airports where type in ("heliport", "balloonport")')
# Out:
#            id    ident      type                             name  \
# 0        6523      00A  heliport                Total Rf Heliport
# 1      322658     00CN  heliport  Kitchen Creek Helibase Heliport
# 2        6532     00FD  heliport               Ringhaver Heliport
# 3        6535     00GE  heliport                 Caffrey Heliport
# 4        6536     00HI  heliport               Kaupulehu Heliport
# ...       ...      ...       ...                              ...
# 13643  312624  ZA-0119  heliport               Cape Town Heliport
# 13644  318475  ZA-0140  heliport        Kuruman Hospital Heliport
# 13645  339169     ZGNT  heliport         Shenzhen Nantou Heliport
# 13646  301278      ZIZ  heliport                 Zamzama Heliport
# 13647   46378  ZZ-0001  heliport                  Sealand Helipad
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070801     -74.933601          11.0      None          US
# 1         32.727374    -116.459742        3350.0      None          US
# 2         28.846600     -82.345398          25.0      None          US
# 3         33.889245     -84.737930         957.0      None          US
# 4         19.832715    -155.980233          43.0      None          US
# ...             ...            ...           ...       ...         ...
# 13643    -33.901018      18.425936           NaN        AF          ZA
# 13644    -27.459904      23.443762           NaN        AF          ZA
# 13645     22.558736     113.925612           NaN        AS          CN
# 13646     26.710944      67.667250         128.0        AS          PK
# 13647     51.894444       1.482500          40.0        EU          GB
#
#       iso_region       municipality scheduled_service gps_code iata_code  \
# 0          US-PA           Bensalem                no      00A      None
# 1          US-CA        Pine Valley                no     00CN      None
# 2          US-FL          Riverview                no     00FD      None
# 3          US-GA              Hiram                no     00GE      None
# 4          US-HI        Kailua-Kona                no     00HI      None
# ...          ...                ...               ...      ...       ...
# 13643      ZA-WC               None                no     None      None
# 13644      ZA-NC            Kuruman                no     None      None
# 13645      CN-44  Nanshan, Shenzhen                no     ZGNT      None
# 13646      PK-SD  Zamzama Gas Field                no     None       ZIZ
# 13647     GB-ENG            Sealand                no     None      None
#
#       local_code                   home_link  \
# 0            00A                        None
# 1           00CN                        None
# 2           00FD                        None
# 3           00GE                        None
# 4           00HI                        None
# ...          ...                         ...
# 13643       None                        None
# 13644       None                        None
# 13645       None                        None
# 13646       None                        None
# 13647       None  http://www.sealandgov.org/
#
#                                           wikipedia_link              keywords
# 0                                                   None                  None
# 1                                                   None                  None
# 2                                                   None                  None
# 3                                                   None                  None
# 4                                                   None                  None
# ...                                                  ...                   ...
# 13643                                               None                  None
# 13644                                               None                  None
# 13645                                               None                  None
# 13646                                               None                  None
# 13647  https://en.wikipedia.org/wiki/Principality_of_...  Roughs Tower Helipad
#
# [13648 rows x 18 columns]

# %%
airports[airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident      type                             name  \
# 0        6523      00A  heliport                Total Rf Heliport
# 9      322658     00CN  heliport  Kitchen Creek Helibase Heliport
# 12       6532     00FD  heliport               Ringhaver Heliport
# 15       6535     00GE  heliport                 Caffrey Heliport
# 16       6536     00HI  heliport               Kaupulehu Heliport
# ...       ...      ...       ...                              ...
# 60831  312624  ZA-0119  heliport               Cape Town Heliport
# 60852  318475  ZA-0140  heliport        Kuruman Hospital Heliport
# 60930  339169     ZGNT  heliport         Shenzhen Nantou Heliport
# 60951  301278      ZIZ  heliport                 Zamzama Heliport
# 61218   46378  ZZ-0001  heliport                  Sealand Helipad
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070801     -74.933601          11.0       NaN          US
# 9         32.727374    -116.459742        3350.0       NaN          US
# 12        28.846600     -82.345398          25.0       NaN          US
# 15        33.889245     -84.737930         957.0       NaN          US
# 16        19.832715    -155.980233          43.0       NaN          US
# ...             ...            ...           ...       ...         ...
# 60831    -33.901018      18.425936           NaN        AF          ZA
# 60852    -27.459904      23.443762           NaN        AF          ZA
# 60930     22.558736     113.925612           NaN        AS          CN
# 60951     26.710944      67.667250         128.0        AS          PK
# 61218     51.894444       1.482500          40.0        EU          GB
#
#       iso_region       municipality scheduled_service gps_code iata_code  \
# 0          US-PA           Bensalem                no      00A       NaN
# 9          US-CA        Pine Valley                no     00CN       NaN
# 12         US-FL          Riverview                no     00FD       NaN
# 15         US-GA              Hiram                no     00GE       NaN
# 16         US-HI        Kailua-Kona                no     00HI       NaN
# ...          ...                ...               ...      ...       ...
# 60831      ZA-WC                NaN                no      NaN       NaN
# 60852      ZA-NC            Kuruman                no      NaN       NaN
# 60930      CN-44  Nanshan, Shenzhen                no     ZGNT       NaN
# 60951      PK-SD  Zamzama Gas Field                no      NaN       ZIZ
# 61218     GB-ENG            Sealand                no      NaN       NaN
#
#       local_code                   home_link  \
# 0            00A                         NaN
# 9           00CN                         NaN
# 12          00FD                         NaN
# 15          00GE                         NaN
# 16          00HI                         NaN
# ...          ...                         ...
# 60831        NaN                         NaN
# 60852        NaN                         NaN
# 60930        NaN                         NaN
# 60951        NaN                         NaN
# 61218        NaN  http://www.sealandgov.org/
#
#                                           wikipedia_link              keywords
# 0                                                    NaN                   NaN
# 9                                                    NaN                   NaN
# 12                                                   NaN                   NaN
# 15                                                   NaN                   NaN
# 16                                                   NaN                   NaN
# ...                                                  ...                   ...
# 60831                                                NaN                   NaN
# 60852                                                NaN                   NaN
# 60930                                                NaN                   NaN
# 60951                                                NaN                   NaN
# 61218  https://en.wikipedia.org/wiki/Principality_of_...  Roughs Tower Helipad
#
# [13648 rows x 18 columns]

# %% [markdown]
# #### Example Query 2: Display all airports who are not heliport or ballonport

# %%
ps.sqldf('select * from airports where type not in ("heliport", "balloonport")')
# Out:
#            id    ident            type                                name  \
# 0      323361     00AA   small_airport                Aero B Ranch Airport
# 1        6524     00AK   small_airport                        Lowell Field
# 2        6525     00AL   small_airport                        Epps Airpark
# 3        6526     00AR          closed  Newport Hospital & Clinic Heliport
# 4      322127     00AS   small_airport                      Fulton Airport
# ...       ...      ...             ...                                 ...
# 47568   27244     ZYYJ  medium_airport         Yanji Chaoyangchuan Airport
# 47569  317861     ZYYK  medium_airport               Yingkou Lanqi Airport
# 47570   32753     ZYYY  medium_airport             Shenyang Dongta Airport
# 47571  307326  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 47572  313629     ZZZZ   small_airport              Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         38.704022    -101.473911        3435.0      None          US
# 1         59.949200    -151.695999         450.0      None          US
# 2         34.864799     -86.770302         820.0      None          US
# 3         35.608700     -91.254898         237.0      None          US
# 4         34.942803     -97.818019        1100.0      None          US
# ...             ...            ...           ...       ...         ...
# 47568     42.882801     129.451004         624.0        AS          CN
# 47569     40.542524     122.358600           NaN        AS          CN
# 47570     41.784401     123.496002           NaN        AS          CN
# 47571    -11.584278      47.296389          11.0        AF          TF
# 47572     30.784722     130.270556         338.0        AS          JP
#
#       iso_region      municipality scheduled_service gps_code iata_code  \
# 0          US-KS             Leoti                no     00AA      None
# 1          US-AK      Anchor Point                no     00AK      None
# 2          US-AL           Harvest                no     00AL      None
# 3          US-AR           Newport                no     None      None
# 4          US-OK              Alex                no     00AS      None
# ...          ...               ...               ...      ...       ...
# 47568      CN-22             Yanji               yes     ZYYJ       YNJ
# 47569      CN-21  Laobian, Yingkou               yes     ZYYK       YKH
# 47570      CN-21  Dadong, Shenyang                no     ZYYY      None
# 47571     TF-U-A  Grande Glorieuse                no     None      None
# 47572      JP-46      Mishima-Mura                no     RJX7      None
#
#       local_code home_link                                     wikipedia_link  \
# 0           00AA      None                                               None
# 1           00AK      None                                               None
# 2           00AL      None                                               None
# 3           None      None                                               None
# 4           00AS      None                                               None
# ...          ...       ...                                                ...
# 47568       None      None  https://en.wikipedia.org/wiki/Yanji_Chaoyangch...
# 47569       None      None  https://en.wikipedia.org/wiki/Yingkou_Lanqi_Ai...
# 47570       None      None                                               None
# 47571       None      None                                               None
# 47572       RJX7      None  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...
#
#                    keywords
# 0                      None
# 1                      None
# 2                      None
# 3                      00AR
# 4                      None
# ...                     ...
# 47568                  None
# 47569                  None
# 47570                  None
# 47571                  None
# 47572  SATSUMA,IWOJIMA,RJX7
#
# [47573 rows x 18 columns]

# %%
airports[~airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident            type                                name  \
# 1      323361     00AA   small_airport                Aero B Ranch Airport
# 2        6524     00AK   small_airport                        Lowell Field
# 3        6525     00AL   small_airport                        Epps Airpark
# 4        6526     00AR          closed  Newport Hospital & Clinic Heliport
# 5      322127     00AS   small_airport                      Fulton Airport
# ...       ...      ...             ...                                 ...
# 61215   27244     ZYYJ  medium_airport         Yanji Chaoyangchuan Airport
# 61216  317861     ZYYK  medium_airport               Yingkou Lanqi Airport
# 61217   32753     ZYYY  medium_airport             Shenyang Dongta Airport
# 61219  307326  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 61220  313629     ZZZZ   small_airport              Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 1         38.704022    -101.473911        3435.0       NaN          US
# 2         59.949200    -151.695999         450.0       NaN          US
# 3         34.864799     -86.770302         820.0       NaN          US
# 4         35.608700     -91.254898         237.0       NaN          US
# 5         34.942803     -97.818019        1100.0       NaN          US
# ...             ...            ...           ...       ...         ...
# 61215     42.882801     129.451004         624.0        AS          CN
# 61216     40.542524     122.358600           NaN        AS          CN
# 61217     41.784401     123.496002           NaN        AS          CN
# 61219    -11.584278      47.296389          11.0        AF          TF
# 61220     30.784722     130.270556         338.0        AS          JP
#
#       iso_region      municipality scheduled_service gps_code iata_code  \
# 1          US-KS             Leoti                no     00AA       NaN
# 2          US-AK      Anchor Point                no     00AK       NaN
# 3          US-AL           Harvest                no     00AL       NaN
# 4          US-AR           Newport                no      NaN       NaN
# 5          US-OK              Alex                no     00AS       NaN
# ...          ...               ...               ...      ...       ...
# 61215      CN-22             Yanji               yes     ZYYJ       YNJ
# 61216      CN-21  Laobian, Yingkou               yes     ZYYK       YKH
# 61217      CN-21  Dadong, Shenyang                no     ZYYY       NaN
# 61219     TF-U-A  Grande Glorieuse                no      NaN       NaN
# 61220      JP-46      Mishima-Mura                no     RJX7       NaN
#
#       local_code home_link                                     wikipedia_link  \
# 1           00AA       NaN                                                NaN
# 2           00AK       NaN                                                NaN
# 3           00AL       NaN                                                NaN
# 4            NaN       NaN                                                NaN
# 5           00AS       NaN                                                NaN
# ...          ...       ...                                                ...
# 61215        NaN       NaN  https://en.wikipedia.org/wiki/Yanji_Chaoyangch...
# 61216        NaN       NaN  https://en.wikipedia.org/wiki/Yingkou_Lanqi_Ai...
# 61217        NaN       NaN                                                NaN
# 61219        NaN       NaN                                                NaN
# 61220       RJX7       NaN  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...
#
#                    keywords
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                      00AR
# 5                       NaN
# ...                     ...
# 61215                   NaN
# 61216                   NaN
# 61217                   NaN
# 61219                   NaN
# 61220  SATSUMA,IWOJIMA,RJX7
#
# [47573 rows x 18 columns]

# %% [markdown]
# ### GROUP BY, COUNT, ORDER BY<a id ='groupby'></a>
#
# The **GROUP BY** statement groups rows that have the same values into summary rows, like "find the number of customers in each country". The **GROUP BY** statement is often used with aggregate functions **(COUNT, MAX, MIN, SUM, AVG)** to group the result-set by one or more columns.
#
# For more information, click [here](https://www.w3schools.com/sql/sql_groupby.asp)
#
# Grouping is straightforward: use the .groupby() operator. There’s a subtle difference between semantics of a COUNT in SQL and Pandas. In Pandas, .count() will return the number of non-null/NaN values. To get the same result as the SQL COUNT, use .size().

# %% [markdown]
# |                                                           SQL                                                           |                                                                     Pandas                                                                    |
# |:-----------------------------------------------------------------------------------------------------------------------:|:---------------------------------------------------------------------------------------------------------------------------------------------:|
# | select iso_country, type, count(&ast;) from airports group by iso_country, type order by iso_country, type              | airports.groupby(['iso_country', 'type']).size()                                                                                              |
# | select iso_country, type, count(&ast;) from airports group by iso_country, type order by iso_country, count(&ast;) desc | airports.groupby(['iso_country', 'type']).size().to_frame('size').sort_values(['iso_country', 'size'], ascending=[True, False]).reset_index() |

# %% [markdown]
# #### Example Query 1:  Count airports if grouped togather and ordered ascending format by country and type

# %%
ps.sqldf('select iso_country, type, count(*) from airports\
         group by iso_country, type order by iso_country, type')
# Out:
#     iso_country            type  count(*)
# 0          None          closed         4
# 1          None   large_airport         1
# 2          None  medium_airport        11
# 3          None   small_airport       230
# 4            AD          closed         1
# ..          ...             ...       ...
# 871          ZM   small_airport        94
# 872          ZW          closed         2
# 873          ZW   large_airport         1
# 874          ZW  medium_airport         8
# 875          ZW   small_airport       128
#
# [876 rows x 3 columns]

# %%
airports.groupby(['iso_country', 'type']).size()
# Out:
# iso_country  type
# AD           closed              1
#              heliport            2
# AE           closed              1
#              heliport           21
#              large_airport       4
#                               ...
# ZM           small_airport      94
# ZW           closed              2
#              large_airport       1
#              medium_airport      8
#              small_airport     128
# Length: 872, dtype: int64

# %% [markdown]
# #### Example Query 2: Count airports if grouped togather and ordered descending format by country and type

# %%
by_country = ps.sqldf('select iso_country, type, count(*) as size from airports\
                      group by iso_country, type order by iso_country, count(*) desc')
by_country
# Out:
#     iso_country            type  size
# 0          None   small_airport   230
# 1          None  medium_airport    11
# 2          None          closed     4
# 3          None   large_airport     1
# 4            AD        heliport     2
# ..          ...             ...   ...
# 871          ZM          closed     1
# 872          ZW   small_airport   128
# 873          ZW  medium_airport     8
# 874          ZW          closed     2
# 875          ZW   large_airport     1
#
# [876 rows x 3 columns]

# %%
airports.groupby(['iso_country', 'type']).size().to_frame(
    'size').sort_values(['iso_country', 'size'], ascending=[True, False])
# Out:
#                             size
# iso_country type
# AD          heliport           2
#             closed             1
# AE          heliport          21
#             small_airport     16
#             medium_airport     7
# ...                          ...
# ZM          large_airport      1
# ZW          small_airport    128
#             medium_airport     8
#             closed             2
#             large_airport      1
#
# [872 rows x 1 columns]

# %% [markdown]
# With .reset_index(), we restart row numbering for our data frame.

# %% [markdown]
# ### HAVING<a id ='having'></a>

# %% [markdown]
# The **HAVING** clause was added to SQL because the **WHERE** keyword could not be used with aggregate functions.
#
# For more information, click [here](https://www.w3schools.com/sql/sql_having.asp)
#
# In SQL, you can additionally filter grouped data using a HAVING condition. In Pandas, you can use .filter() and provide a Python function (or a lambda) that will return True if the group should be included into the result.

# %% [markdown]
# |                                                                     SQL                                                                     |                                                                   Pandas                                                                   |
# |:-------------------------------------------------------------------------------------------------------------------------------------------:|:------------------------------------------------------------------------------------------------------------------------------------------:|
# | select type, count(&ast;) from airports where iso_country = 'US' group by type having count(&ast;) > 1000 order by count(&ast;) desc | airports[airports.iso_country == 'US'].groupby('type').filter(lambda g: len(g) > 1000).groupby('type').size().sort_values(ascending=False) |

# %% [markdown]
# #### Example Query: Count and display airport type where country is USA and grouped by type and displayed only if their count is greater than 100 and arrange it in descending format

# %%
ps.sqldf('select type, count(*) from airports\
         where iso_country = "US" group by type having count(*) > 1000\
         order by count(*) desc')
# Out:
#             type  count(*)
# 0  small_airport     13774
# 1       heliport      6652
# 2         closed      2891

# %%
airports[airports.iso_country == 'US'].groupby('type').filter(
    lambda g: len(g) > 1000).groupby('type').size().sort_values(
    ascending=False)
# Out:
# type
# small_airport    13774
# heliport          6652
# closed            2891
# dtype: int64

# %% [markdown]
# ### Top N Records<a id ='records'></a>

# %% [markdown]
# |                                    SQL                                   |                           Pandas                          |
# |:------------------------------------------------------------------------:|:---------------------------------------------------------:|
# | select iso_country from by_country order by size desc limit 10           | by_country.nlargest(10, columns='size')['iso_country']         |
# | select iso_country from by_country order by size desc limit 10 offset 10 | by_country.nlargest(20, columns='size')['iso_country'].tail(10) |

# %% [markdown]
# #### Example Query 1: Select top 10 countries with the largest count

# %%
ps.sqldf('select iso_country from by_country order by size desc limit 10')
# Out:
#   iso_country
# 0          US
# 1          US
# 2          BR
# 3          US
# 4          AU
# 5          BR
# 6          KR
# 7          MX
# 8          CA
# 9          JP

# %%
by_country.nlargest(10, columns='size')['iso_country']
# Out:
# 814    US
# 815    US
# 109    BR
# 816    US
# 50     AU
# 110    BR
# 441    KR
# 555    MX
# 138    CA
# 414    JP
# Name: iso_country, dtype: object

# %% [markdown]
# #### Example Query 2: Select 10 countries with the first top 10 countries having the largest count

# %%
ps.sqldf('select iso_country from by_country order by size desc limit 10 offset 10')
# Out:
#   iso_country
# 0          GB
# 1          DE
# 2          US
# 3          CA
# 4          AR
# 5          CO
# 6          US
# 7          RU
# 8          IT
# 9          PG

# %%
by_country.nlargest(20, columns='size')['iso_country'].tail(10)
# Out:
# 286    GB
# 204    DE
# 817    US
# 139    CA
# 36     AR
# 176    CO
# 818    US
# 675    RU
# 398    IT
# 621    PG
# Name: iso_country, dtype: object

# %% [markdown]
# ### Aggregate functions (MIN, MAX, MEAN)<a id ='Agg'></a>

# %% [markdown]
# |                                           SQL                                          |                            Pandas                            |
# |:--------------------------------------------------------------------------------------:|:------------------------------------------------------------:|
# | select max(length_ft), min(length_ft), avg(length_ft) from runways | runways.agg({'length_ft': ['min', 'max', 'mean', 'median']}) |

# %% [markdown]
# #### Example Query: Select runways that have max and min length, also calculate the mean length of runways.

# %%
ps.sqldf('select max(length_ft), min(length_ft), avg(length_ft) from runways')
# Out:
#    max(length_ft)  min(length_ft)  avg(length_ft)
# 0        120000.0             0.0     3264.651573

# %%
runways.agg({'length_ft': ['max', 'min', 'mean']})
# Out:
#           length_ft
# max   120000.000000
# min        0.000000
# mean    3264.651573

# %% [markdown]
# ### UNION<a id ='Union'></a>

# %% [markdown]
# The UNION operator is used to combine the result-set of two or more SELECT statements.
#
# For more information, click [here](https://www.w3schools.com/sql/sql_union.asp)

# %% [markdown]
# |                                                                 SQL                                                                 |                                                                  Pandas                                                                 |
# |:-----------------------------------------------------------------------------------------------------------------------------------:|:---------------------------------------------------------------------------------------------------------------------------------------:|
# | select name, municipality from airports where ident = 'KLAX' union all select name, municipality from airports where ident = 'KLGB' | pd.concat([airports[airports.ident == 'KLAX'][['name', 'municipality']], airports[airports.ident == 'KLGB'][['name', 'municipality']]]) |

# %% [markdown]
# #### Example Query: Show combined result sets that contain the name and muncipality of airports for idents "KLAX" and "KLGB"

# %%
ps.sqldf('select name, municipality from airports where ident = "KLAX"\
         union all select name, municipality from airports where ident = "KLGB"')
# Out:
#                                    name municipality
# 0     Los Angeles International Airport  Los Angeles
# 1  Long Beach Airport (Daugherty Field)   Long Beach

# %%
pd.concat([airports[airports.ident == 'KLAX'][['name', 'municipality']],
           airports[airports.ident == 'KLGB'][['name', 'municipality']]])
# Out:
#                                        name municipality
# 30803     Los Angeles International Airport  Los Angeles
# 30828  Long Beach Airport (Daugherty Field)   Long Beach

# %% [markdown]
# ----

# %% [markdown]
# Hope you enjoyed reading this and learned something new ! Feel free to provide any feedback and connect with me.
#
# Thanks !
#
# Perpared by Asad Mahmood.
